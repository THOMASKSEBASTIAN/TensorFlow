# %% [markdown]
# Step 1: Understanding the Basics
# What is TensorFlow?
#
# TensorFlow is an open-source framework developed by Google for building and training machine learning models.
# It supports deep learning and traditional ML techniques.
# Prerequisites
#
# Basic Python programming knowledge.
# Familiarity with basic linear algebra and calculus concepts.
# Understanding of machine learning basics (optional but helpful).
# Install TensorFlow

# %% [markdown]
# Step 2: Theoretical Foundations
# Core Concepts
#
# Tensors: The fundamental data structure (similar to NumPy arrays).
# Graph and Session (TF1.x) or Eager Execution (TF2.x): Computation graph for efficient model training.
# Operations: Mathematical operations on tensors.
# Key Components
#
# Layers and Models: Building blocks for creating neural networks.
# Optimizers: Algorithms for training models.
# Loss Functions: Quantify the error during training.
# Machine Learning Workflow
#
# Data preprocessing.
# Model building.
# Model training and evaluation.

# %% [markdown]
# Step 3: Practical Learning Path

# %% [markdown]
# Setup a Development Environment
#
# Use Jupyter Notebook or Google Colab for experiments.

# %% [markdown]
# Start with Simple Examples
#
# Hello, TensorFlow:

# %%
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
a = tf.constant(10)
b = tf.constant(3)
c = a + b
print("Result:", c)
# Out:
# TensorFlow version: 2.18.0
# Result: tf.Tensor(13, shape=(), dtype=int32)

# %% [markdown]
# Basic Neural Network: Train a simple linear regression model.

# %%
import tensorflow as tf
import numpy as np

# Data
X = np.array([1, 2, 3, 4], dtype=np.float32)
y = np.array([2, 4, 6, 8], dtype=np.float32)

# Model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=1, input_shape=[1])
])

# Compile
model.compile(optimizer='sgd', loss='mean_squared_error')

# Train
model.fit(X, y, epochs=500)
# Out:
# Epoch 1/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - loss: 6.0592
# Epoch 2/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 4.2081
# Epoch 3/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 2.9237
# Epoch 4/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 2.0324
# Epoch 5/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 1.4139
# Epoch 6/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.9848
# Epoch 7/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.6870
# Epoch 8/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.4803
# Epoch 9/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.3369
# Epoch 10/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.2373
# Epoch 11/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.1683
# Epoch 12/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.1203
# Epoch 13/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0870
# Epoch 14/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0639
# Epoch 15/500
# ...

# %%
x = np.array([5], dtype=np.float32)
print("Prediction:", model.predict(x))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Prediction: [[9.9571295]]
